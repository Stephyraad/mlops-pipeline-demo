# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/employee_attrition_dataset.csv')

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Marital_Status Department   Job_Role  Job_Level  \
# 0            1   58  Female        Married         IT    Manager          1
# 1            2   48  Female        Married      Sales  Assistant          5
# 2            3   34    Male        Married  Marketing  Assistant          1
# 3            4   27  Female       Divorced  Marketing    Manager          1
# 4            5   40    Male       Divorced  Marketing  Executive          1
#
#    Monthly_Income  Hourly_Rate  Years_at_Company  ...  Overtime  \
# 0           15488           28                15  ...        No
# 1           13079           28                 6  ...       Yes
# 2           13744           24                24  ...       Yes
# 3            6809           26                10  ...        No
# 4           10206           52                29  ...        No
#
#    Project_Count  Average_Hours_Worked_Per_Week  Absenteeism  \
# ...

# %%
# NOMINAL_FEATURES
# ['Gender', 'Marital_Status', 'Department', 'Job_Role','Overtime']
print("Nominal Features")
print(f"Gender: {df['Gender'].unique()}")
print(f"Marital Status: {df['Marital_Status'].unique()}")
print(f"Department: {df['Department'].unique()}")
print(f"Job Role: {df['Job_Role'].unique()}")
print(f"Overtime: {df['Overtime'].unique()}")

# ORDINAL_FEATURES
# ['Job_Level']
print('\n')
print('Ordinal Features')
print(f"Job Level: {df['Job_Level'].unique()}")
# Out:
# Nominal Features
# Gender: ['Female' 'Male']
# Marital Status: ['Married' 'Divorced' 'Single']
# Department: ['IT' 'Sales' 'Marketing' 'Finance' 'HR']
# Job Role: ['Manager' 'Assistant' 'Executive' 'Analyst']
# Overtime: ['No' 'Yes']
#
#
# Ordinal Features
# Job Level: [1 5 3 2 4]
